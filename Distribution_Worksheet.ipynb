# %% [markdown]
# ## For each problem below draw a picture of the normal curve and shade the area you have to find. Let Z represent a variable following a standard normal distribution.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math#
# Constant #

# %%
mu = 998.8 
sigma = 73.10
x1 = 900
x2 = 1100

z1 = (x1 - mu) / sigma
z2 = (x2 - mu) / sigma

x_all = np.arange(-10, 10, 0.001)
y2 = stats.norm.pdf(x_all,0,1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x_all,y2)

ax.set_xlim([-4,4])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Normal Gaussian Curve')

plt.show()
# Out:
# -1.3515731874145003
# 1.3844049247606027

# %%
### Find the proportion that is less than z=2.00.

# First step is to find the z-score
# z = (input - mean) / deviation
# 2 = (input - 998.8) / 73.10
# x = 1145

# 0 bound 
z1 = -4
# z = 2
z2 = 2
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x_all,y2)

ax.set_xlim([-4,4])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Normal Gaussian Curve')


ax.fill_between(x,y,0, alpha=0.1, color='b')

plt.plot()
# Out:
# []

# %%
### Find the proportion that is between z = -.13 and z = 1.75.

# 0 bound 
z1 = -0.13
# z = 2
z2 = 1.75
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x_all,y2)

ax.set_xlim([-4,4])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Normal Gaussian Curve')


ax.fill_between(x,y,0, alpha=0.1, color='b')

plt.plot()
# Out:
# []

# %%
### Find the proportion that is greater than z=1.86.
# 0 bound 
z1 = 1.86
# z = 2
z2 = 4
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x_all,y2)

ax.set_xlim([-4,4])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Normal Gaussian Curve')


ax.fill_between(x,y,0, alpha=0.1, color='b')

plt.plot()
# Out:
# []

# %%
### Find the z-score for the 64th percentile.
# Using the z table for normal distribution z = 0.36

# %%
### Find the z-scores that bound the middle 50% of all data
# z = 0.00

# %%
### Find the z-score for the 24th percentile.
# Using the z table for normal distribution z = 0.7

# %% [markdown]
# ## Former ISU basketball player Kelvin Cato is 83 inches tall. Assuming that heights follow approximately a normal distribution with mean 70 and standard deviation o = 3

# %%
mean = 70
sigma = 3
x = np.arange(-10, 10, 0.001)
y = stats.norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x,y)

ax.set_xlim([-5,5])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Height of Men')

plt.show()

# %%
### what is his corresponding z-score?
# z = (83 - mean) / sigma
# z = (83 - 70) / 3
# z = 2.3

# %%
### what proportion of men are taller than him?
# Following the z table, Kevin's height is at the 59th percentile of the distribution. Which mean the percentile of men that are taller than him is 41 %.abs

z1 = 2.33333
z2 = 4

x = np.arange(-10, 10, 0.001)
y = stats.norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x,y)

ax.set_xlim([-5,5])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Height of Men')

x1 = np.arange(z1,z2, 0.001)
y2 = stats.norm.pdf(x1,0,1)

ax.fill_between(x1,y2,0, alpha=0.1, color='b')

plt.plot()
# Out:
# []

# %% [markdown]
# #  Since the length of a downhill ski is related to the height of the individuals renting them, it is fair to assume that a normal distribution would describe the length of women’s skis at rental outlets in Colorado. The mean of the distribution is 150 cm and the standard deviation is 10 cm.

# %%
mean = 150
sigma = 10
x = np.arange(-10, 10, 0.001)
y = stats.norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x,y)

ax.set_xlim([-5,5])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Women\'s ski lengths')

plt.show()

# %%
# What is the proportion of women’s ski lengths that are less than 130 cm?
# z = (130 - mean) / sigma
# z = (130 - 150) / 10
# z = -2

z1 = -5
z2 = -2 


x = np.arange(-10, 10, 0.001)
y = stats.norm.pdf(x,0,1)

x1 = np.arange(z1, z2, 0.001)
y1 = stats.norm.pdf(x1, 0, 1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x,y)

ax.set_xlim([-5,5])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Women\'s ski lengths')

ax.fill_between(x1, y1, color='b')
plt.show()

# %%
# What is the proportion of women’s ski lengths that are greater than 125 cm?
# z = (125 - mean) / sigma
# z = (125 - 150) / 10
# z = -2.5

z1 = -2.5
z2 = 4


x = np.arange(-10, 10, 0.001)
y = stats.norm.pdf(x,0,1)

x1 = np.arange(z1, z2, 0.001)
y1 = stats.norm.pdf(x1, 0, 1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x,y)

ax.set_xlim([-5,5])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Women\'s ski lengths')

ax.fill_between(x1, y1, color='b')
plt.show()

# %%
# What is the proportion of women’s ski lengths that are between 125 and 155?
# z1 = (125 - mean) / sigma
# z1 = (125 - 150) / 10
# z1 = -2.5
# z2 = (155 - mean) / sigma
# z2 = (155 - 150) / 10
# z2 = 0.5

z1 = -2.5
z2 = 0.5


x = np.arange(-10, 10, 0.001)
y = stats.norm.pdf(x,0,1)

x1 = np.arange(z1, z2, 0.001)
y1 = stats.norm.pdf(x1, 0, 1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x,y)

ax.set_xlim([-5,5])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Women\'s ski lengths')

ax.fill_between(x1, y1, color='b')
plt.show()

# %%
# Very long skies are expensive and there are not many people who rent them. What is the longest women’s ski a rental shop should carry so that only 2 percent of the costumers will ask to rent a longer ski?

# Using the z table to find the z-score that had ~0.98 percent. Then using that z-score to find x
# z = 2.3
# 2.3 = (x - 150) / 10
# x = 173

z1 = 2.3
z2 = 4


x = np.arange(-10, 10, 0.001)
y = stats.norm.pdf(x,0,1)

x1 = np.arange(z1, z2, 0.001)
y1 = stats.norm.pdf(x1, 0, 1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x,y)

ax.set_xlim([-5,5])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Women\'s ski lengths')

ax.fill_between(x1, y1, color='b')
plt.show()

# %% [markdown]
# ## The BMI for males age 20 to 74 is follows approximately a normal distribution with mean μ = 27.9 and standard deviation o = 7.8. Use the 68-95-99.7 rule to find

# %%
mean = 27.9
sigma = 7.8

x = np.arange(-10, 10, 0.001)
y = stats.norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x,y)

ax.set_xlim([-5,5])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Males\' BMI age 20 - 74')

plt.show()

# %%
### the percentage of males with BMI less than 20.1.
# Using 68-95-99.7 rule. 
# 50 - 34 = 16
# 16 percent

# %%
### the percentages of males with BMI greater than 12.3.
# Using 68-95-99.7 rule. 
# 100 - (2 devivation) = x
# 100 - 13.5 = 86.5
# 86.5 percent of males with BMI greater than 12.3

# %%
### the BMI values that correspond to the middle 99.7% of the distribution.
# 27.9

# %%
### the value such that 0.15% of males have BMI’s greater than the value.
# 3 deviation
# 3 = (x - mean) / sigma
# 3 = (x - 27.9) / 7.8
# 23.4 + 27.9 = x
# x = 51.3
